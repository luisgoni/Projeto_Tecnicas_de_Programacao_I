# %%
import pandas as pd
import numpy as np

# %%
df_2023 = pd.read_csv(r'C:\Users\João Varella\OneDrive\Área de Trabalho\Projeto_Banco_de_Dados_João_VArella\Projeto_Tecnicas_de_Programacao_I\data\World Happiness Report 2023.csv')
df_2023.head(5)
# Out:
#   Country name  Ladder score  Standard error of ladder score  upperwhisker  \
# 0      Finland         7.804                           0.036         7.875
# 1      Denmark         7.586                           0.041         7.667
# 2      Iceland         7.530                           0.049         7.625
# 3       Israel         7.473                           0.032         7.535
# 4  Netherlands         7.403                           0.029         7.460
#
#    lowerwhisker  Logged GDP per capita  Social support  \
# 0         7.733                 10.792           0.969
# 1         7.506                 10.962           0.954
# 2         7.434                 10.896           0.983
# 3         7.411                 10.639           0.943
# 4         7.346                 10.942           0.930
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                   71.150                         0.961      -0.019
# ...

# %%
df_2023.rename(columns={'Country name':'Country',
                        'Ladder score':'Score',
                        'Explained by: Log GDP per capita':'GDP per capita',
                        'Explained by: Perceptions of corruption':'Perceptions of corruption',
                        'Explained by: Generosity':'Generosity',
                        'Explained by: Freedom to make life choices':'Freedom to make life choices'
                        })
# Out:
#               Country  Score  Standard error of ladder score  upperwhisker  \
# 0             Finland  7.804                           0.036         7.875
# 1             Denmark  7.586                           0.041         7.667
# 2             Iceland  7.530                           0.049         7.625
# 3              Israel  7.473                           0.032         7.535
# 4         Netherlands  7.403                           0.029         7.460
# ..                ...    ...                             ...           ...
# 132  Congo (Kinshasa)  3.207                           0.095         3.394
# 133          Zimbabwe  3.204                           0.061         3.323
# 134      Sierra Leone  3.138                           0.082         3.299
# 135           Lebanon  2.392                           0.044         2.479
# 136       Afghanistan  1.859                           0.033         1.923
#
#      lowerwhisker  Logged GDP per capita  Social support  \
# ...

# %%
df_2022 = pd.read_csv(r'C:\Users\João Varella\OneDrive\Área de Trabalho\Projeto_Banco_de_Dados_João_VArella\Projeto_Tecnicas_de_Programacao_I\data\World Happiness Report 2022.csv')
df_2022.head(5)
# Out:
#    RANK      Country  Happiness score  Whisker-high  Whisker-low  \
# 0     1      Finland            7.821         7.886        7.756
# 1     2      Denmark            7.636         7.710        7.563
# 2     3      Iceland            7.557         7.651        7.464
# 3     4  Switzerland            7.512         7.586        7.437
# 4     5  Netherlands            7.415         7.471        7.359
#
#    Dystopia (1.83) + residual  Explained by: GDP per capita  \
# 0                       2.518                         1.892
# 1                       2.226                         1.953
# 2                       2.320                         1.936
# 3                       2.153                         2.026
# 4                       2.137                         1.945
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                         1.258                                  0.775
# ...

# %%
df_2022 = pd.read_csv(r'C:\Users\João Varella\OneDrive\Área de Trabalho\Projeto_Banco_de_Dados_João_VArella\Projeto_Tecnicas_de_Programacao_I\data\World Happiness Report 2023.csv')
df_2022.head(5)
# Out:
#   Country name  Ladder score  Standard error of ladder score  upperwhisker  \
# 0      Finland         7.804                           0.036         7.875
# 1      Denmark         7.586                           0.041         7.667
# 2      Iceland         7.530                           0.049         7.625
# 3       Israel         7.473                           0.032         7.535
# 4  Netherlands         7.403                           0.029         7.460
#
#    lowerwhisker  Logged GDP per capita  Social support  \
# 0         7.733                 10.792           0.969
# 1         7.506                 10.962           0.954
# 2         7.434                 10.896           0.983
# 3         7.411                 10.639           0.943
# 4         7.346                 10.942           0.930
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                   71.150                         0.961      -0.019
# ...

# %%
df_2022['Year'] = 2022

# %%
df_2022 = df_2022[['Country name','Ladder score','Explained by: Log GDP per capita','Explained by: Social support','Explained by: Healthy life expectancy','Explained by: Freedom to make life choices','Explained by: Generosity','Explained by: Perceptions of corruption','Year']]
df_2022.head(5)
# Out:
#   Country name  Ladder score  Explained by: Log GDP per capita  \
# 0      Finland         7.804                             1.888
# 1      Denmark         7.586                             1.949
# 2      Iceland         7.530                             1.926
# 3       Israel         7.473                             1.833
# 4  Netherlands         7.403                             1.942
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                         1.585                                  0.535
# 1                         1.548                                  0.537
# 2                         1.620                                  0.559
# 3                         1.521                                  0.577
# 4                         1.488                                  0.545
#
#    Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                       0.772                     0.126
# ...

# %%
df_2023['Year'] = 2023

# %%
df_2023 = df_2023[['Country name','Ladder score','Explained by: Log GDP per capita','Explained by: Social support','Explained by: Healthy life expectancy','Explained by: Freedom to make life choices','Explained by: Generosity','Explained by: Perceptions of corruption','Year']]
df_2023
# Out:
#          Country name  Ladder score  Explained by: Log GDP per capita  \
# 0             Finland         7.804                             1.888
# 1             Denmark         7.586                             1.949
# 2             Iceland         7.530                             1.926
# 3              Israel         7.473                             1.833
# 4         Netherlands         7.403                             1.942
# ..                ...           ...                               ...
# 132  Congo (Kinshasa)         3.207                             0.531
# 133          Zimbabwe         3.204                             0.758
# 134      Sierra Leone         3.138                             0.670
# 135           Lebanon         2.392                             1.417
# 136       Afghanistan         1.859                             0.645
#
#      Explained by: Social support  Explained by: Healthy life expectancy  \
# ...
